# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasquant/Iniciacao_Cientifica/blob/main/VQE_IBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install pylatexenc

# %%
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit import QuantumCircuit

theta = Parameter("θ")

qc = QuantumCircuit(3)
qc.rx(theta, 0)
qc.cx(0, 1)
qc.x(2)

qc.draw("mpl")

# %%
from math import pi
# definindo um circuito parametrizado com angulos
angle_list = [pi / 3, pi / 2]
circuits = [qc.assign_parameters({theta: angle}) for angle in angle_list]

for circuit in circuits:
    display(circuit.draw("mpl"))
